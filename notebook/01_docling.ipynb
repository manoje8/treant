# %%
from pathlib import Path

from treant.constants import ParseMethod
from treant.treant import process_document
from treant.utils import separate_content

# %%
html_path = "document/entra-id-lecture.html"
pdf_path = "document/crysstallization-main.pdf"
txt_path = ""
md_path = "document/module_1_core_python.md"
docx_path = ""
img_path = "document/java_roadmap.png"
xls_path = "document/ComplexExpressions-1.xlsx"

# %%
file_path = Path().cwd().parent / pdf_path

# %%
file_path

# %%
content_list, doc_id = await process_document(file_path, ParseMethod.DOCLING, display_stats=True)

# %%
content_list

# %%
text, multi, block = separate_content(content_list)

# %%
text
